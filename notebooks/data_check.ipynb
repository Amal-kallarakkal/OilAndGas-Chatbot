# %%
import pandas as pd

# %%
Equipment = pd.read_csv("C:\\Users\\amal.kallarakkal\\Oil&Gas_ChatBot\\data\\equipment_health.csv")
Prod = pd.read_csv("C:\\Users\\amal.kallarakkal\\Oil&Gas_ChatBot\\data\\production_data.csv")
Equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29240 entries, 0 to 29239
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                29240 non-null  object
#  1   asset_id            29240 non-null  object
#  2   well_id             29240 non-null  object
#  3   equipment_type      29240 non-null  object
#  4   vibration_level     29240 non-null  float64
#  5   temperature_c       29240 non-null  float64
#  6   pressure_psi        29240 non-null  float64
#  7   failure_risk_score  29240 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 1.8+ MB

# %%
Prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29240 entries, 0 to 29239
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              29240 non-null  object
#  1   asset_id          29240 non-null  object
#  2   well_id           29240 non-null  object
#  3   oil_produced_bbl  29240 non-null  float64
#  4   gas_produced_mcf  29240 non-null  float64
#  5   water_cut_pct     29240 non-null  float64
#  6   downtime_hours    29240 non-null  int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ MB
